# %%
import xarray as xr
import numpy as np
import pandas as pd

# %%
data = xr.DataArray(np.random.randn(2, 3), dims=("x", "y"), coords={"x": [10, 20]})

data
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[ 1.50278272, -0.3297203 ,  0.68902124],
#        [-0.78946772,  1.37292636, -0.11262147]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y

# %%
xr.DataArray(pd.Series(range(3), index=list("abc"), name="foo"))
# Out:
# <xarray.DataArray 'foo' (dim_0: 3)>
# array([0, 1, 2])
# Coordinates:
#   * dim_0    (dim_0) object 'a' 'b' 'c'

# %%
# data.values

# data.dims

data.coords

# data.attrs
# Out:
# Coordinates:
#   * x        (x) int64 10 20

# %%
data = xr.DataArray( [[1,2],[3,4],[5,6]], dims=("x", "y"), coords={"x": [0,1,2]})
data2 = xr.DataArray( [[1,2],[3,4],[5,6]], dims=("x", "y"))

# %%
data.attrs["koniec"] = "tak"

# %%
data -  data2
# Out:
# <xarray.DataArray (x: 3, y: 2)>
# array([[0, 0],
#        [0, 0],
#        [0, 0]])
# Coordinates:
#   * x        (x) int64 0 1 2
# Dimensions without coordinates: y

# %%
data.name = "Hello"

# %%
data
# Out:
# <xarray.DataArray 'Hello' (x: 3, y: 2)>
# array([[1, 2],
#        [3, 4],
#        [5, 6]])
# Coordinates:
#   * x        (x) int64 0 1 2
# Dimensions without coordinates: y
# Attributes:
#     koniec:   tak

# %%
df= pd.DataFrame({"one": [1,2,3,4], "two": [5,6,7,8]})

# %%
df
# Out:
#    one  two
# 0    1    5
# 1    2    6
# 2    3    7
# 3    4    8

# %%
data = xr.DataArray(df)

# %%
data
# Out:
# <xarray.DataArray (dim_0: 4, dim_1: 2)>
# array([[1, 5],
#        [2, 6],
#        [3, 7],
#        [4, 8]])
# Coordinates:
#   * dim_0    (dim_0) int64 0 1 2 3
#   * dim_1    (dim_1) object 'one' 'two'

# %%
data.sel(dim_1="one")
# Out:
# <xarray.DataArray (dim_0: 4)>
# array([1, 2, 3, 4])
# Coordinates:
#   * dim_0    (dim_0) int64 0 1 2 3
#     dim_1    <U3 'one'

# %%
data[:,0]
# Out:
# <xarray.DataArray (dim_0: 4)>
# array([1, 2, 3, 4])
# Coordinates:
#   * dim_0    (dim_0) int64 0 1 2 3
#     dim_1    <U3 'one'

# %%
data.sum(dim="dim_0")
# Out:
# <xarray.DataArray (dim_1: 2)>
# array([10, 26])
# Coordinates:
#   * dim_1    (dim_1) object 'one' 'two'

# %%
data.coords = (["idx"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_11229/3380922315.py in <module>
# ----> 1 data.coords = (["idx"])
#
# ~/.local/lib/python3.9/site-packages/xarray/core/common.py in __setattr__(self, name, value)
#     265         """
#     266         try:
# --> 267             object.__setattr__(self, name, value)
#     268         except AttributeError as e:
#     269             # Don't accidentally shadow custom AttributeErrors, e.g.
#
# AttributeError: can't set attribute
