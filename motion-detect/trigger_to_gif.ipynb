# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from Trigger import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_5566/2774523140.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 import pandas as pd
#       4 from Trigger import *
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv("test.csv")
df.sort_values(["file"], inplace=True, ascending=False)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5566/4017564391.py in <module>
# ----> 1 df = pd.read_csv("test.csv")
#       2 df.sort_values(["file"], inplace=True, ascending=False)
#       3 df
#
# NameError: name 'pd' is not defined

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'file', 'length', 'start_frame', 'end_frame',
#        'rect_min_x', 'rect_min_y', 'rect_max_x', 'rect_max_y', 'section',
#        'time_block', 'line_fit'],
#       dtype='object')

# %%
triggers = read_df(df)

# %%
def gen_gif(trigger, out_filename, size=None):
    b_box = trigger.bounding_rect
    frames = get_frames(trigger)
    c_rect = center_rect(trigger, Vec2(100,100))
    frames = [cut_rect_from_frame(mark_rect(frame,b_box, thickness=1), c_rect) for frame in frames]
    animate(frames, interactive=False, file=out_filename, size=size)

# %%
gen_gif(triggers[0], "out.gif")
# Out:
# Rect(min_x=1657.5, min_y=494.5, max_x=1856.5, max_y=693.5)

# %%
for trigger in triggers:
    gen_gif(trigger, str(trigger.file) + ".gif")
# Out:
# Rect(min_x=1657.5, min_y=494.5, max_x=1856.5, max_y=693.5)
# Rect(min_x=1318.0, min_y=300.0, max_x=1517.0, max_y=499.0)
# Rect(min_x=40.0, min_y=348.0, max_x=239.0, max_y=547.0)
# Rect(min_x=1595.5, min_y=899.5, max_x=1794.5, max_y=1079)
# Rect(min_x=1691.5, min_y=369.0, max_x=1890.5, max_y=568.0)
# Rect(min_x=895.0, min_y=739.0, max_x=1094.0, max_y=938.0)
# Rect(min_x=620.0, min_y=749.5, max_x=819.0, max_y=948.5)
# Rect(min_x=13.5, min_y=630.0, max_x=212.5, max_y=829.0)
# Rect(min_x=532.0, min_y=485.0, max_x=731.0, max_y=684.0)
# Rect(min_x=969.5, min_y=744.0, max_x=1168.5, max_y=943.0)
# Rect(min_x=1635.0, min_y=0, max_x=1834.0, max_y=139.0)
# Rect(min_x=1027.5, min_y=380.0, max_x=1226.5, max_y=579.0)
# Rect(min_x=934.0, min_y=0, max_x=1133.0, max_y=188.5)
# Rect(min_x=1724.0, min_y=657.0, max_x=1919, max_y=856.0)

# %%
trigger
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5566/4284265512.py in <module>
# ----> 1 trigger
#
# NameError: name 'trigger' is not defined
